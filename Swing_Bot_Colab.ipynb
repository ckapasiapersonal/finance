# %% [markdown]
# # 🏁 Indian Swing Terminal - Cloud Runner
# Run this notebook daily to scan the market and update your paper portfolio.

# %%
# !pip install -r requirements.txt

# %%
from daily_scan import run_daily_scan

# Enter your daily Access Token from https://kite.trade/connect/login?api_key=...
access_token = input("Enter Access Token: ")

run_daily_scan(access_token)

# %%
import pandas as pd

print("--- Trade Log ---")
try:
    print(pd.read_csv("trades.csv").tail())
except: print("No trades yet.")

print("\n--- Portfolio ---")
try:
    print(pd.read_csv("portfolio.csv"))
except: print("Empty.")
